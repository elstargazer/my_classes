# %% [markdown]
# ### Import packages

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Heslop and Roberts conglomerate test

# %%
#pdf of mean of Fisher distribution

def 

plt.plot([1, 2, 3, 4])
plt.ylabel('some numbers')
plt.show()

# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, t, 'ro', t, t**2, 'bs', t, t**3, 'g^')
plt.show()
