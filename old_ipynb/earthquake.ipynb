# %%
library(ggplot2)

df <- read.csv(file = '/Users/rogerfu/Dropbox/my_classes/EPS_102_2021/final_projects/seismology/US_earthquakes_since_2001.csv', stringsAsFactors = FALSE)
df
# Out:
#     time                     latitude longitude  depth     mag  magType nst
# 1   2021-03-31T08:56:25.940Z 32.39033 -115.2498  19.220000 4.75 mw       54
# 2   2021-03-17T04:19:28.359Z 31.65433 -104.3573   6.182983 4.50 ml       53
# 3   2021-01-20T14:59:43.686Z 26.59410 -110.9635  10.000000 4.70 mb       NA
# 4   2020-12-14T21:20:10.831Z 38.15540 -118.1231   5.200000 4.70 ml       33
# 5   2020-12-12T07:50:52.930Z 38.14970 -118.1008   6.400000 4.90 ml       30
# 6   2020-12-03T05:15:29.993Z 38.17500 -118.0654   5.000000 4.90 ml       30
# 7   2020-12-01T23:32:56.573Z 38.16370 -118.0837   5.000000 5.10 ml       21
# 8   2020-11-13T09:13:51.862Z 38.16930 -117.8533   4.800000 5.30 ml       34
# 9   2020-10-24T10:11:07.260Z 25.72240 -110.1051  10.000000 4.60 mb       NA
# 10  2020-10-01T00:31:27.340Z 33.05600 -115.5898  11.540000 4.93 mw      111
# 11  2020-09-24T23:06:42.138Z 27.07790 -111.2685  10.000000 4.60 mb       NA
# ...

# %%
nrow(df)
# Out:
# [1] 581

# %%
df <- read.csv(file = '/Users/rogerfu/Dropbox/my_classes/EPS_102_2021/final_projects/asteroids/asteroids.csv', stringsAsFactors = FALSE)
df
nrow(df)
# Out:
#        pdes      name       diameter albedo rot_per   spec_T a
# 1      1         Ceres      939.400  0.0900  9.074170 G      2.766089
# 2      2         Pallas     545.000  0.1010  7.813200 B      2.774382
# 3      3         Juno       246.596  0.2140  7.210000 S      2.668020
# 4      4         Vesta      525.400  0.4228  5.342128 V      2.362030
# 5      5         Astraea    106.699  0.2740 16.806000 S      2.573621
# 6      6         Hebe       185.180  0.2679  7.274500 S      2.424564
# 7      7         Iris       199.830  0.2766  7.139000 S      2.387139
# 8      8         Flora      147.491  0.2260 12.865000 S      2.201374
# 9      9         Metis      190.000  0.1180  5.079000 S      2.386085
# 10     10        Hygiea     407.120  0.0717 27.630000 C      3.142660
# 11     11        Parthenope 142.887  0.1910 13.720400 S      2.452381
# 12     12        Victoria   115.087  0.1630  8.659900 S      2.333469
# ...
